# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

import 2_openai.deep_research.planner_agent
from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If seven people can build seven tables in seven days, how many days will it take for three people to build three tables?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step:
#
# **Given:**
# - 7 people can build 7 tables in 7 days.
#
# **Find:**
# - How many days will it take 3 people to build 3 tables?
#
# ---
#
# ### Step 1: Understand the rate at which one person builds tables.
#
# If 7 people build 7 tables in 7 days, let's find out how many tables one person can build in one day.
#
# - Total work done = 7 tables.
# - Total person-days = 7 people × 7 days = 49 person-days.
#
# So, in 49 person-days, 7 tables are built.
#
# **Therefore, one table requires:**
#
# \[
# \frac{49 \text{ person-days}}{7 \text{ tables}} = 7 \text{ person-days per table}
# \]
#
# Meaning, to build one table, it takes 7 person-days.
#
# ---
#
# ### Step 2: Find out how long it will take 3 people to build 3 tables.
#
# - Building 3 tables requires \(3 \times 7 = 21\) person-days in total.
#
# - With 3 people working, the number of person-days completed per day is 3.
#
# - Number of days needed = \(\frac{21 \text{ person-days}}{3 \text{ people}} = 7 \text{ days}\).
#
# ---
#
# ### **Answer:**
#
# It will take **7 days** for 3 people to build 3 tables.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step:
#
# **Given:**
# - 7 people can build 7 tables in 7 days.
#
# **Find:**
# - How many days will it take 3 people to build 3 tables?
#
# ---
#
# ### Step 1: Understand the rate at which one person builds tables.
#
# If 7 people build 7 tables in 7 days, let's find out how many tables one person can build in one day.
#
# - Total work done = 7 tables.
# - Total person-days = 7 people × 7 days = 49 person-days.
#
# So, in 49 person-days, 7 tables are built.
#
# **Therefore, one table requires:**
#
# \[
# \frac{49 \text{ person-days}}{7 \text{ tables}} = 7 \text{ person-days per table}
# \]
#
# Meaning, to build one table, it takes 7 person-days.
#
# ---
#
# ### Step 2: Find out how long it will take 3 people to build 3 tables.
#
# - Building 3 tables requires \(3 \times 7 = 21\) person-days in total.
#
# - With 3 people working, the number of person-days completed per day is 3.
#
# - Number of days needed = \(\frac{21 \text{ person-days}}{3 \text{ people}} = 7 \text{ days}\).
#
# ---
#
# ### **Answer:**
#
# It will take **7 days** for 3 people to build 3 tables.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Something here"}]

# Then make the first call:

response =

# Then read the business idea:

business_idea = response.

# And repeat! In the next message, include the business idea within the message

# %% [markdown]
# from ai_tools import

# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..','..')))
from ai_tools.tools import LLMQuery

SYSTEM_PROMPT = """You are an Expert AI Business Analyst, understanding the challenges of an industry."""

planer = LLMQuery(model="gemini-3.1-pro-preview")
response = planer.query("What business area is worth exploring for an Agentic AI opportunity, focus on data engineering, DWH and similar concepts?", display_output=True)
# Out:
# The intersection of **Agentic AI** (AI that can plan, use tools, and execute multi-step workflows autonomously) and **Data Engineering/Data Warehousing (DWH)** is one of the most lucrative, untapped frontiers in tech.
#
# While traditional Generative AI has focused on "Text-to-SQL" for analysts, Data Engineering is ripe for Agentic AI because the work is highly structured, relies on code (Python, SQL, YAML), and has clear success/failure metrics (unit tests, DAG completions).
#
# Here are the most promising business areas worth exploring for an Agentic AI opportunity in this space:
#
# ---
#
# ### 1. Autonomous Data Quality & Incident Remediation
# **The Problem:** Data pipelines break constantly due to upstream schema changes, null values, or API limits. Currently, a Data Engineer gets an alert, manually traces the lineage, finds the broken code, writes a fix, and triggers a backfill.
# **The Agentic Opportunity:**
# Build an "AI On-Call Data Engineer." When an Airflow or dbt pipeline fails:
# *   The agent reads the error log.
# *   It queries the metadata/lineage graph to find the root cause.
# *   It generates a fix (e.g., casting a new data type, handling a null).
# *   It tests the fix in a sandbox environment.
# *   It submits a Pull Request (PR) in GitHub with a summary of the issue and fix.
# *   *Advanced:* It autonomously orchestrates the data backfill once the PR is merged.
# **Business Value:** Massive reduction in Data Engineering operational overhead (Ops) and downtime.
#
# ### 2. DWH FinOps & Autonomous Optimization
# **The Problem:** Cloud data warehouses (Snowflake, BigQuery, Databricks) are notoriously expensive. Companies waste millions on poorly written queries, redundant data models, and oversized compute clusters.
# **The Agentic Opportunity:**
# An agent that continuously acts as a database administrator/optimizer:
# *   It monitors query history logs and identifies inefficient full-table scans or repetitive joins.
# *   It autonomously rewrites the SQL to be more efficient.
# *   It evaluates if a Materialized View or new clustering/partition key would save money, tests the hypothesis, and applies it.
# *   It dynamically scales DWH compute resources up and down based on predictive workload analysis.
# **Business Value:** Direct, quantifiable ROI. You can price this software as a percentage of the cloud compute cost it saves the customer.
#
# ### 3. Legacy-to-Modern DWH Migration (The "Translator" Agent)
# **The Problem:** Enterprises are still stuck on legacy on-premise databases (Teradata, Oracle, Hadoop) because migrating thousands of proprietary Stored Procedures to modern cloud syntax (Snowflake/dbt) takes years of expensive consulting.
# **The Agentic Opportunity:**
# An agentic workflow designed for large-scale migrations:
# *   The agent ingests legacy stored procedures and maps the proprietary logic.
# *   It breaks down monolithic scripts into modular, DAG-based dbt models.
# *   **Crucial Agentic Step:** It writes the new code, runs both the old and new code against a sample dataset, compares the outputs, and iteratively debugs its own code until the outputs match exactly (parity testing).
# **Business Value:** This disrupts the multi-billion-dollar system integration and consulting market. It turns a 2-year project into a 2-month project.
#
# ### 4. Dynamic API Ingestion & Pipeline Generation
# **The Problem:** Building a new connector for a niche API or an internal microservice requires reading documentation, writing Python requests, handling pagination, and dealing with rate limits.
# **The Agentic Opportunity:**
# An agent that builds robust "Zero-to-One" ELT pipelines based on prompts:
# *   A user asks: *"Ingest customer data from the ACME CRM API into Snowflake."*
# *   The agent crawls the ACME API documentation.
# *   It writes the Python code to handle authentication, pagination, and error handling.
# *   It generates the DDL (Data Definition Language) statements to create the landing tables in the DWH.
# *   It creates the initial dbt staging models to normalize the JSON responses.
# **Business Value:** Dramatically speeds up time-to-insight and democratizes data ingestion for analytics engineers and operations teams.
#
# ### 5. Automated Data Documentation and Governance
# **The Problem:** Nobody documents data pipelines. Data catalogs (like Alation or Collibra) are often empty graveyards because DEs hate writing descriptions for hundreds of columns.
# **The Agentic Opportunity:**
# An agent that continuously reverse-engineers context:
# *   It reads the DWH schema, the transformation code (dbt), and BI dashboard queries (Looker/Tableau).
# *   It deduces what a table means based on how the business *actually uses it* in dashboards.
# *   It automatically writes high-quality, business-friendly descriptions for tables and columns and pushes them to the data catalog.
# *   It tags PII (Personally Identifiable Information) autonomously to ensure compliance (GDPR/HIPAA).
# **Business Value:** Solves the massive enterprise data governance problem without requiring human behavioral changes.
#
# ### 6. Semantic Layer & Metric Definition Management
# **The Problem:** Defining a metric like "Active User" or "Annual Recurring Revenue" across a company is a mess of conflicting SQL queries.
# **The Agentic Opportunity:**
# An agent that helps construct and maintain a Universal Semantic Layer:
# *   It scans all BI tool queries to find discrepancies in how metrics are calculated.
# *   It suggests a unified metric definition and generates the YAML/code for modern semantic layers (like Cube or dbt Semantic Layer).
# *   If the underlying DWH schema changes, the agent automatically updates the Semantic Layer definitions so downstream dashboards don't break.
# **Business Value:** Creates a "single source of truth" and eliminates the friction between data teams and business stakeholders.
#
# ---
#
# ### How to Evaluate Which to Pursue:
#
# If you are looking to build a startup or a new product in this space, evaluate these areas using the **"Read vs. Write" risk matrix**.
#
# *   **Low Risk / High Demand:** *Documentation, FinOps recommendations, Data Quality alerting.* (The agent mostly reads data and suggests changes).
# *   **High Risk / Massive Reward:** *Autonomous remediation, Pipeline generation, Automated migrations.* (The agent writes code and executes it).
#
# **The Winning Strategy:** Start by building an agent that *suggests* PRs (Human-in-the-loop). Once data engineers trust that the agent writes good dbt/SQL code and understands their specific DAG, you can introduce fully autonomous execution.
# 'The intersection of **Agentic AI** (AI that can plan, use tools, and execute multi-step workflows autonomously) and **Data Engineering/Data Warehousing (DWH)** is one of the most lucrative, untapped frontiers in tech. \n\nWhile traditional Generative AI has focused on "Text-to-SQL" for analysts, Data Engineering is ripe for Agentic AI because the work is highly structured, relies on code (Python, SQL, YAML), and has clear success/failure metrics (unit tests, DAG completions).\n\nHere are the most promising business areas worth exploring for an Agentic AI opportunity in this space:\n\n---\n\n### 1. Autonomous Data Quality & Incident Remediation\n**The Problem:** Data pipelines break constantly due to upstream schema changes, null values, or API limits. Currently, a Data Engineer gets an alert, manually traces the lineage, finds the broken code, writes a fix, and triggers a backfill.\n**The Agentic Opportunity:** \nBuild an "AI On-Call Data Engineer." When an Airflow or dbt pipeline fails:\n*   The agent reads the error log.\n*   It queries the metadata/lineage graph to find the root cause.\n*   It generates a fix (e.g., casting a new data type, handling a null).\n*   It tests the fix in a sandbox environment.\n*   It submits a Pull Request (PR) in GitHub with a summary of the issue and fix.\n*   *Advanced:* It autonomously orchestrates the data backfill once the PR is merged.\n**Business Value:** Massive reduction in Data Engineering operational overhead (Ops) and downtime.\n\n### 2. DWH FinOps & Autonomous Optimization\n**The Problem:** Cloud data warehouses (Snowflake, BigQuery, Databricks) are notoriously expensive. Companies waste millions on poorly written queries, redundant data models, and oversized compute clusters.\n**The Agentic Opportunity:**\nAn agent that continuously acts as a database administrator/optimizer:\n*   It monitors query history logs and identifies inefficient full-table scans or repetitive joins.\n*   It autonomously rewrites the SQL to be more efficient.\n*   It evaluates if a Materialized View or new clustering/partition key would save money, tests the hypothesis, and applies it.\n*   It dynamically scales DWH compute resources up and down based on predictive workload analysis.\n**Business Value:** Direct, quantifiable ROI. You can price this software as a percentage of the cloud compute cost it saves the customer.\n\n### 3. Legacy-to-Modern DWH Migration (The "Translator" Agent)\n**The Problem:** Enterprises are still stuck on legacy on-premise databases (Teradata, Oracle, Hadoop) because migrating thousands of proprietary Stored Procedures to modern cloud syntax (Snowflake/dbt) takes years of expensive consulting.\n**The Agentic Opportunity:**\nAn agentic workflow designed for large-scale migrations:\n*   The agent ingests legacy stored procedures and maps the proprietary logic.\n*   It breaks down monolithic scripts into modular, DAG-based dbt models.\n*   **Crucial Agentic Step:** It writes the new code, runs both the old and new code against a sample dataset, compares the outputs, and iteratively debugs its own code until the outputs match exactly (parity testing).\n**Business Value:** This disrupts the multi-billion-dollar system integration and consulting market. It turns a 2-year project into a 2-month project.\n\n### 4. Dynamic API Ingestion & Pipeline Generation\n**The Problem:** Building a new connector for a niche API or an internal microservice requires reading documentation, writing Python requests, handling pagination, and dealing with rate limits. \n**The Agentic Opportunity:**\nAn agent that builds robust "Zero-to-One" ELT pipelines based on prompts:\n*   A user asks: *"Ingest customer data from the ACME CRM API into Snowflake."*\n*   The agent crawls the ACME API documentation.\n*   It writes the Python code to handle authentication, pagination, and error handling.\n*   It generates the DDL (Data Definition Language) statements to create the landing tables in the DWH.\n*   It crea ...

# %%
response_solution = planer.query("Propose an agentic solution for 4. Dynamic API Ingestion & Pipeline Generation", display_output=True)
# Out:
# Here is a comprehensive proposal for an agentic solution tackling **Dynamic API Ingestion & Pipeline Generation**.
#
# Let’s call this conceptual product **OmniPipe AI**: an agentic system that transforms natural language requests and API documentation into production-ready, self-healing data pipelines.
#
# ---
#
# ### 1. The Core Concept: Why Agentic?
# Traditional GenAI (like ChatGPT) can write a Python script for an API, but it usually fails on the first run due to pagination quirks, strict rate limits, or missing headers.
#
# **OmniPipe AI** is *agentic* because it has a **Self-Correction Execution Loop**. It doesn't just write code; it executes the code in a secure sandbox, reads the error logs (e.g., 401 Unauthorized, 429 Too Many Requests), modifies its own code to fix the issue, and tries again until data successfully lands.
#
# ---
#
# ### 2. Multi-Agent Architecture
# To make this reliable, the solution should not rely on one massive LLM prompt. It should utilize a **Multi-Agent framework** (using tools like LangGraph or CrewAI), where specialized agents pass tasks to one another.
#
# *   **🕵️‍♂️ The Researcher Agent:**
#     *   **Input:** A link to API documentation (or OpenAPI/Swagger spec) and a user prompt (e.g., *"Extract all historical tickets from Zendesk"*).
#     *   **Action:** Crawls the docs. Maps out the endpoints, required authentication methods, pagination logic (cursor-based, offset, etc.), and rate limits.
#     *   **Output:** A structured JSON "Integration Spec."
# *   **🧑‍💻 The Pipeline Engineer Agent:**
#     *   **Input:** The Integration Spec.
#     *   **Action:** Writes the actual Python code. *Pro-tip: Instead of raw Python, have the agent write code using an open-source framework like **dlt (Data Load Tool)** or **Airbyte CDK**, which inherently handles state management and chunking.*
# *   **🧪 The QA & Execution Agent (The crucial piece):**
#     *   **Action:** Executes the Python script inside a secure, ephemeral sandbox (e.g., using E2B or secure Docker).
#     *   **Loop:** If the script fails, this agent captures the stack trace, sends it back to the Engineer Agent with instructions to fix it, and re-tests.
# *   **🏗️ The DWH Architect Agent:**
#     *   **Action:** Once data is successfully pulled, this agent inspects the raw JSON payloads. It automatically generates the DDL (table creation scripts) for Snowflake/BigQuery and writes the baseline **dbt staging models** (casting types, renaming columns, unnesting JSON arrays).
#
# ---
#
# ### 3. Step-by-Step User Workflow (Human-in-the-Loop)
#
# Security and trust are paramount in Data Engineering. The system should be highly autonomous but require human approval at key gates.
#
# **Step 1: The Request**
# The Data Engineer inputs the API documentation URL, the desired endpoints, and selects a secure vault credential (the agent never reads the raw API keys, it uses environment variable references).
#
# **Step 2: The Agentic Loop (Autonomous)**
# The agents research, code, execute, and debug in the background. The user sees a terminal-like interface showing the agent's "thoughts" (e.g., *"Attempt 1 failed: Pagination cursor not found in response. Modifying script to check response headers. Attempt 2..."*).
#
# **Step 3: The PR Generation**
# OmniPipe AI does not deploy directly to production. Instead, it opens a Pull Request in the company’s GitHub/GitLab containing:
# 1.  The Python extraction script.
# 2.  The Dockerfile / Airflow DAG to schedule it.
# 3.  The dbt `.sql` and `.yml` files for the transformation.
# 4.  A markdown summary of the API limits and schema structure.
#
# **Step 4: Human Review & Merge**
# The human Data Engineer reviews the code. If they want changes, they comment on the PR: *"Change the ingestion frequency from daily to hourly."* The agent reads the comment, updates the code, and commits the change. Once approved, the standard CI/CD pipeline takes over.
#
# ---
#
# ### 4. Technical Stack Recommendation
#
# To build this product today, you would leverage the following stack:
#
# *   **LLM Layer:** **Claude 3.5 Sonnet** (Currently the best model for coding and following complex syntax rules) or **GPT-4o**.
# *   **Agentic Framework:** **LangGraph**. It allows you to build cyclic graphs (loops) which are necessary for the "Execute -> Fail -> Fix -> Execute" loop.
# *   **Code Execution Sandbox:** **E2B (English2Bits)** or **Docker**. You need a secure, isolated environment where the agent can run network requests without exposing your host machine to malicious code.
# *   **Ingestion Engine:** **dlt (data load tool)**. Instead of teaching the AI to write complex database `INSERT` statements, teach it to write `dlt` sources. `dlt` automatically normalizes nested JSON and infers schemas, making the agent's job 10x easier.
# *   **Vector DB (Optional):** **Pinecone or Qdrant**. To store previous API integrations the agent has built, allowing it to learn from past successes using RAG (Retrieval-Augmented Generation).
#
# ---
#
# ### 5. Go-To-Market & Business Value
#
# **The Competitors:** Fivetran, Airbyte, Meltano.
# **The Gap:** Fivetran is incredible for the top 500 APIs (Salesforce, Stripe, Shopify). But enterprise companies use *thousands* of niche SaaS tools, legacy software, and internal microservices that have no pre-built connectors. Data Engineers spend 30-40% of their time building and maintaining bespoke pipelines for this "long tail" of data sources.
#
# **The Value Proposition:**
# 1.  **Zero-to-One in Minutes:** Reduce the time to build a custom API connector from 2 weeks to 20 minutes.
# 2.  **Self-Healing Maintenance:** APIs evolve. When an API provider adds a mandatory parameter and breaks the pipeline, the QA Agent intercepts the Airflow failure, diagnoses the API change, and submits a hotfix PR autonomously.
# 3.  **Standardization:** Humans write bespoke pipelines in highly varied ways. An agent writes standard, heavily documented, framework-compliant code every single time.
#
# ### How to start building this tomorrow (MVP):
# 1. Pick one framework (`dlt`).
# 2. Hardcode the API documentation for a public API (e.g., Rick and Morty API or a weather API) into a prompt.
# 3. Build a simple Python script using LangChain that writes the code, executes it via `subprocess`, parses the `stderr`, and rewrites it if it fails.
# 4. Once it can reliably ingest a public API without auth, add the complexity of Authentication, Pagination, and Schema Generation.
